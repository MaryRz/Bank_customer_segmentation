# %% [markdown]
# <p style="text-align:right">&nbsp;</p>
#
# <p style="text-align:right">&nbsp;</p>
#
# <p style="text-align:right"><span style="font-family:Courier New,Courier,monospace"><strong><span style="font-size:28px"><span style="background-color:#f39c12">&nbsp;رفتار استفاده حدود 9000 دارنده کارت اعتباری فعال در شش ماه</span></span></strong></span></p>
#
# <p style="text-align:right"><span style="font-family:Courier New,Courier,monospace"><strong><span style="font-size:28px"><span style="background-color:#f39c12">داده مشتریان </span></span></strong></span><span style="background-color:#f39c12">🙂&nbsp;</span><span style="font-family:Courier New,Courier,monospace"><strong><span style="font-size:28px"><span style="background-color:#f39c12">با 18 متغیر رفتاری</span></span></strong></span></p>
#
# <p style="text-align:right">&nbsp;</p>
#
# <pre>
# <span style="font-family:Courier New,Courier,monospace"><strong><span style="background-color:#f39c12">&#39;CUST_ID&#39;,</span>
# <span style="background-color:#f39c12">&#39;BALANCE&#39;,</span>
# <span style="background-color:#f39c12">&#39;BALANCE_FREQUENCY&#39;,</span>
# <span style="background-color:#f39c12">&#39;PURCHASES&#39;,</span>
# <span style="background-color:#f39c12">&#39;ONEOFF_PURCHASES&#39;,</span>
# <span style="background-color:#f39c12">&#39;INSTALLMENTS_PURCHASES&#39;,</span>
# <span style="background-color:#f39c12">&#39;CASH_ADVANCE&#39;,
# &#39;PURCHASES_FREQUENCY&#39;,</span>
# <span style="background-color:#f39c12">&#39;ONEOFF_PURCHASES_FREQUENCY&#39;,</span>
# <span style="background-color:#f39c12">&#39;PURCHASES_INSTALLMENTS_FREQUENCY&#39;,</span>
# <span style="background-color:#f39c12">&#39;CASH_ADVANCE_FREQUENCY&#39;,
# &#39;CASH_ADVANCE_TRX&#39;,</span>
# <span style="background-color:#f39c12">&#39;PURCHASES_TRX&#39;,</span>
# <span style="background-color:#f39c12">&#39;CREDIT_LIMIT&#39;,</span>
# <span style="background-color:#f39c12">&#39;PAYMENTS&#39;,</span>
# <span style="background-color:#f39c12">&#39;MINIMUM_PAYMENTS&#39;,</span>
# <span style="background-color:#f39c12">&#39;PRC_FULL_PAYMENT&#39;,</span>
# <span style="background-color:#f39c12">&#39;TENURE&#39;],</span></strong></span></pre>
#
# <p style="text-align:right">&nbsp;</p>

# %% [markdown]
# داده های رفتاری حدود 9000 دارنده کارت اعتباری فعال در شش ماه موجود می باشد. این داده ها دارای ۱۸ متغیر می باشند.

# %% [markdown]
# تراز مالی ماهانه سالانه
# خریدها نقدی و اقساطی
# تکرار خرید

# %% [markdown]
# مقدار واقعی پول موجود در حساب، تزار گفته می شود

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Path to the PNG image
img_path = './image/Data Dictionary.png'
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import pandas as pd

# %%
CreditCardData = pd.read_csv('CC GENERAL.csv')

# %%
CreditCardData.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
CreditCardData.shape
# Out:
# (8950, 18)

# %%
CreditCardData.head(3)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
# 2                         1.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# ...

# %%
CreditCardData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
CreditCardData.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
CreditCardData.shape
# Out:
# (8950, 18)

# %%
CreditCardData.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots with one row and two columns
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the first boxplot of CREDIT_LIMIT
sns.boxplot(y="CREDIT_LIMIT", data=CreditCardData, ax=axes[0])
axes[0].set_title("Box plot of CREDIT LIMIT")

# Plot the second boxplot of MINIMUM_PAYMENTS
sns.boxplot(y="MINIMUM_PAYMENTS", data=CreditCardData, ax=axes[1])
axes[1].set_title("Box plot of MINIMUM_PAYMENTS")

# Display the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# <p style="text-align:right"><span style="color:#f39c12"><span style="font-size:22px"><strong><span style="font-family:Courier New,Courier,monospace">رفع مشکل داده های ازدست رفته</span></strong></span></span></p>

# %% [markdown]
# <p style="text-align:right"><span style="color:#f39c12"><span style="font-size:22px"><strong><span style="font-family:Courier New,Courier,monospace">در باکس پلات دیدیم که داده ها دارای انحراف هستند، بنابراین از میانه برای نسبت دادن داده های از دست رفته استفاده می کنیم.</span></strong></span></span></p>

# %%
#Impute with median
CreditCardData['CREDIT_LIMIT'].fillna(CreditCardData['CREDIT_LIMIT'].median(),inplace = True)
CreditCardData['MINIMUM_PAYMENTS'].fillna(CreditCardData['MINIMUM_PAYMENTS'].median(),inplace = True)

# %% [markdown]
# <p style="direction:rtl; text-align:right"><span style="color:#f39c12"><span style="font-size:22px"><strong><span style="font-family:Courier New,Courier,monospace">استخراج KPI های جدید</span></strong></span></span></p>

# %%
import numpy as np
def purchasetype(x):
    if   (x["ONEOFF_PURCHASES"] == 0) & (x["INSTALLMENTS_PURCHASES"] == 0):
        return("NONE")
    elif (x["ONEOFF_PURCHASES"] > 0)  & (x["INSTALLMENTS_PURCHASES"] == 0):
        return("ONEOFF")
    elif (x["ONEOFF_PURCHASES"] == 0) & (x["INSTALLMENTS_PURCHASES"] > 0):
        return("INSTALLMENTS")
    elif (x["ONEOFF_PURCHASES"] > 0)  & (x["INSTALLMENTS_PURCHASES"] > 0):
        return("BOTH_ONEOFF_INSTALLMENTS")
#====================================================================================================
CreditCardData["Purchase_Type"] = CreditCardData.apply(purchasetype,axis=1)
#====================================================================================================

CreditCardData["Monthly_Avg_Purchase"] = CreditCardData["PURCHASES"]/CreditCardData["TENURE"]
CreditCardData["Balance_Credit_Ratio"] = CreditCardData["BALANCE"]/CreditCardData["CREDIT_LIMIT"]
CreditCardData["Monthly_Cash_Advance"] = CreditCardData["CASH_ADVANCE"]/CreditCardData["TENURE"]
#added where clause to avoid division by zero
CreditCardData["Total_Payment_Ratio"] = np.where(CreditCardData["MINIMUM_PAYMENTS"] == 0,
                                                 CreditCardData["MINIMUM_PAYMENTS"],
                                                 CreditCardData["PAYMENTS"]/CreditCardData["MINIMUM_PAYMENTS"])
CreditCardData = CreditCardData.round(2)

# %%
CreditCardData.shape
# Out:
# (8950, 23)

# %% [markdown]
# <p style="text-align:right"><span style="color:#f39c12"><span style="font-size:22px"><strong><span style="font-family:Courier New,Courier,monospace">استخراج متغیر طبقه بندی بر اساس رفتار کاربر</span></strong></span></span></p>

# %%
CreditCardData.head(3)
# Out:
#   CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.90               0.82      95.40              0.00
# 1  C10002  3202.47               0.91       0.00              0.00
# 2  C10003  2495.15               1.00     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4          0.00                 0.17
# 1                     0.0       6442.95                 0.00
# 2                     0.0          0.00                 1.00
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                         0.0                              0.08  ...
# 1                         0.0                              0.00  ...
# 2                         1.0                              0.00  ...
#
#    CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# 0        1000.0    201.80            139.51              0.00      12
# ...

# %%
CreditCardData.head(3)
# Out:
#   CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.90               0.82      95.40              0.00
# 1  C10002  3202.47               0.91       0.00              0.00
# 2  C10003  2495.15               1.00     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4          0.00                 0.17
# 1                     0.0       6442.95                 0.00
# 2                     0.0          0.00                 1.00
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                         0.0                              0.08  ...
# 1                         0.0                              0.00  ...
# 2                         1.0                              0.00  ...
#
#    CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# 0        1000.0    201.80            139.51              0.00      12
# ...

# %%
# Grouped data
average_total_payment_ratio = CreditCardData.groupby("Purchase_Type")["Total_Payment_Ratio"].mean()
monthly_cash_advance        = CreditCardData.groupby("Purchase_Type")["Monthly_Cash_Advance"].mean()
balance_credit_ratio        = CreditCardData.groupby("Purchase_Type")["Balance_Credit_Ratio"].mean()
monthly_avg_purchase        = CreditCardData.groupby("Purchase_Type")["Monthly_Avg_Purchase"].mean()
#====================================================================================================
import matplotlib.pyplot as plt
# Creating subplots in a 2x2 grid
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 3))
axes[0, 0].set_facecolor('lightblue')
axes[0, 1].set_facecolor('lightgreen')
axes[1, 0].set_facecolor('lightyellow')
axes[1, 1].set_facecolor('lightpink')
#====================================================================================================
# Plotting on the first row
average_total_payment_ratio.plot.barh(ax=axes[0, 0], xlabel="Average Total Payment Ratio")
monthly_cash_advance.plot.barh(       ax=axes[0, 1],        xlabel="Monthly Cash Advance")
# Plotting on the second row
balance_credit_ratio.plot.barh(       ax=axes[1, 0],        xlabel="Balance Credit Ratio")
monthly_avg_purchase.plot.barh(       ax=axes[1, 1],        xlabel="Monthly Average Purchase")
# Adjusting the layout of subplots
plt.tight_layout()
# Displaying the plot
plt.show()

# %%
CreditCardData.shape
# Out:
# (8950, 23)

# %%
creditcarddata_numeric = CreditCardData._get_numeric_data()
creditcarddata_numeric.head(3)
# Out:
#    BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.90               0.82      95.40              0.00
# 1  3202.47               0.91       0.00              0.00
# 2  2495.15               1.00     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4          0.00                 0.17
# 1                     0.0       6442.95                 0.00
# 2                     0.0          0.00                 1.00
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                              0.08
# 1                         0.0                              0.00
# 2                         1.0                              0.00
#
#    CASH_ADVANCE_FREQUENCY  ...  PURCHASES_TRX  CREDIT_LIMIT  PAYMENTS  \
# 0                    0.00  ...              2        1000.0    201.80
# 1                    0.25  ...              0        7000.0   4103.03
# ...

# %%
print(CreditCardData.shape)
print(creditcarddata_numeric.shape)
print('ستون های غیر عددی حذف شدند')
catergorical_variable_names = [x for x in list(CreditCardData.columns) if x not in creditcarddata_numeric]
print(catergorical_variable_names)
# Out:
# (8950, 23)
# (8950, 21)
# ستون های غیر عددی حذف شدند
# ['CUST_ID', 'Purchase_Type']

# %%
catergorical_variable_names.remove("CUST_ID")
catergorical_variable_names
# Out:
# ['Purchase_Type']

# %%
CreditCardData['Purchase_Type'].unique()
# Out:
# array(['INSTALLMENTS', 'NONE', 'ONEOFF', 'BOTH_ONEOFF_INSTALLMENTS'],
#       dtype=object)

# %%
#  using one-hot encoding
dummies = pd.get_dummies(CreditCardData['Purchase_Type'])
dummies.columns
# Out:
# Index(['BOTH_ONEOFF_INSTALLMENTS', 'INSTALLMENTS', 'NONE', 'ONEOFF'], dtype='object')

# %%
credit_log = creditcarddata_numeric.apply(lambda x: np.log(x + 1))

# %%
creditcarddata_merged = pd.concat([credit_log,dummies],axis = 1)

# %%
creditcarddata_org = pd.concat([CreditCardData,dummies],axis=1)

# %%
##dropping the variables used to create the KPI
var_names = ["BALANCE","PURCHASES","PAYMENTS","MINIMUM_PAYMENTS",
             "PRC_FULL_PAYMENT","TENURE","CASH_ADVANCE","CREDIT_LIMIT"]
var_names = ["BALANCE","PURCHASES","PAYMENTS","MINIMUM_PAYMENTS",
             "TENURE","CASH_ADVANCE","CREDIT_LIMIT"]
# 1.PURCHASES
# 2.TENURE
# 3.BALANCE
# 4.CREDIT_LIMIT
# 5.CASH_ADVANCE
# 6.MINIMUM_PAYMENTS
# 7.PAYMENTS
print(len(creditcarddata_merged.columns))
creditcarddata_new = creditcarddata_merged[[x for x in creditcarddata_merged.columns if x not in var_names]]
print(len(creditcarddata_new.columns))
# Out:
# 25
# 18

# %%
creditcarddata_new.shape
# Out:
# (8950, 18)

# %%
from sklearn import metrics
from sklearn.cluster import KMeans

# %% [markdown]
# ### Check for multicollinearity

# %%
#creating a heatmap for better visualization
print(f"Corr for {creditcarddata_new.shape[1]} Features")

plt.figure(figsize=(10,8))
sns.heatmap(creditcarddata_new.corr(),annot=True,fmt=".2f",cmap="viridis")
plt.show()
# Out:
# Corr for 18 Features

# %% [markdown]
# ### Standardization of data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
creditcard_scaled = sc.fit_transform(creditcarddata_new)
pd.DataFrame(creditcard_scaled).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.142125 -0.987090  0.394480 -0.735407 -0.730659 -0.685101 -0.722422
# 1  0.182143 -0.987090 -1.087454 -1.301095 -0.730659 -0.958062  0.700554
# 2  0.491479  1.062022 -1.087454  1.196332  2.466195 -0.958062 -0.722422
# 3 -0.841767  1.265778 -1.087454 -1.023803 -0.375708 -0.958062 -0.231645
# 4  0.491479 -0.114307 -1.087454 -1.023803 -0.375708 -0.958062 -0.722422
#
#          7         8         9         10        11        12        13  \
# 0 -0.810069 -0.579510 -0.555320 -0.429027 -1.026036 -0.890667 -0.490909
# 1  0.784603 -1.379210  0.384073 -1.523368  0.329056  1.697280  0.231093
# 2 -0.810069  0.487865 -0.555320  0.564288 -0.043487 -0.890667 -0.712111
# 3 -0.123281 -0.874655 -0.555320  0.891178 -0.388349  0.302395 -1.444087
# 4 -0.810069 -0.874655 -0.555320 -1.101008  0.889753 -0.890667 -0.032464
#
#          14        15        16        17
# 0 -0.670193  1.720516 -0.543690 -0.514625
# ...

# %% [markdown]
# https://www.gatevidyalay.com/tag/principal-component-analysis-numerical-example/

# %%
from sklearn.decomposition import PCA

# %% [markdown]
#  explained_variance_ratio_  :
#  <br>
#       مقدار اطلاعات حفظ شده توسط هر جزء اصلی را کمی می کند
#    هرچه ابعاد بیشتری را کاهش دهیم سطح تفسیرکنندگی داده ها را نیز کاهش خواهیم داد
#       بنابراین باید مصالحه ای بین ابعاد و سطح تفسیرکنندگی داشته باشیم
# یک رویکرد رایج این است که تعداد مؤلفه‌هایی را انتخاب کنیم که در آن نسبت واریانس توضیح داده شده تجمعی در یک بازه مانند 80% یا 90% قرار می گیرد.

# %%
#applying the PCA to find the number of factors

variance_ratio = {}
for n in range(2,18):
    pc = PCA(n_components=n)
    cr_pca = pc.fit(creditcard_scaled)
    variance_ratio[n] = sum(cr_pca.explained_variance_ratio_)
    print(10*'=')
    print(f"n: {n}","SUM : ",round(variance_ratio[n],2),cr_pca.explained_variance_ratio_)
    print(10*'=')
variance_ratio
# Out:
# ...
# n: 2 SUM :  0.56 [0.38774682 0.17396007]
# ...
# n: 3 SUM :  0.7 [0.38774682 0.17396007 0.13981539]
# ...
# n: 4 SUM :  0.79 [0.38774682 0.17396007 0.13981539 0.08616397]
# ...
# n: 5 SUM :  0.85 [0.38774682 0.17396007 0.13981539 0.08616397 0.06300068]
# ...
# n: 6 SUM :  0.9 [0.38774682 0.17396007 0.13981539 0.08616397 0.06300068 0.04726196]
# ...
# n: 7 SUM :  0.92 [0.38774682 0.17396007 0.13981539 0.08616397 0.06300068 0.04726196
#  0.02694217]
# ...
# n: 8 SUM :  0.94 [0.38774682 0.17396007 0.13981539 0.08616397 0.06300068 0.04726196
#  0.02694217 0.02003981]
# ...
# n: 9 SUM :  0.96 [0.38774682 0.17396007 0.13981539 0.08616397 0.06300068 0.04726196
#  0.02694217 0.02003981 0.01885422]
# ...
# n: 10 SUM :  0.98 [0.38774682 0.17396007 0.13981539 0.08616397 0.06300068 0.04726196
#  0.02694217 0.02003981 0.01885422 0.01166671]
# ...
# n: 11 SUM :  0.98 [0.38774682 0.17396007 0.13981539 0.08616397 0.06300068 0.04726196
#  0.02694217 0.02003981 0.01885422 0.01166671 0.00910113]
# ...

# %%
final_pc = PCA(n_components=5).fit(creditcard_scaled)

reduced_creditdata = final_pc.fit_transform(creditcard_scaled)

# %%
#main data set has 17 components
creditcard_scaled.shape
# Out:
# (8950, 18)

# %%
#after doing pca we got 5 components
reduced_creditdata.shape
# Out:
# (8950, 5)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
scores = []
inertia = []
k_range = range(3, 12)
for k in k_range:
    km = KMeans(n_clusters=k, random_state=2, n_init=10)
    km.fit(creditcard_scaled)
    scores.append(silhouette_score(creditcard_scaled, km.labels_))
    inertia.append(km.inertia_)

# %%
#plotting the sc scores
plt.plot(k_range,scores)
# plt.plot(k_range,inertia)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette Coefficient")
plt.grid()
plt.show()

# %%
km_4 = KMeans(n_clusters=4,random_state=123)
km_4.fit(reduced_creditdata)
# Out:
# C:\ProgramData\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4, random_state=123)

# %%
km_4.labels_
# Out:
# array([0, 1, 2, ..., 0, 1, 2])

# %%
print(len(km_4.labels_))
# Out:
# 8950

# %%
#distribution of labels

pd.Series(km_5.labels_).value_counts()
# Out:
# 3    2756
# 0    2217
# 1    2102
# 2    1875
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.scatter(reduced_creditdata[:,0],reduced_creditdata[:,1],c=km_5.labels_,cmap="Spectral",alpha = 0.1,marker='*')
plt.xlabel("PC_0 & PC_1")
# Add cluster numbers as text on the plot
cluster_centers = km_5.cluster_centers_
for i, center in enumerate(cluster_centers):
    plt.text(center[0], center[1], str(i), fontsize=12, color='black', weight='bold')
plt.show()

# %%
col_key_kpi = ["PURCHASES_TRX","Monthly_Avg_Purchase","Monthly_Cash_Advance",
               "Balance_Credit_Ratio","CASH_ADVANCE_TRX","Total_Payment_Ratio",
               'BOTH_ONEOFF_INSTALLMENTS', 'INSTALLMENTS', 'NONE', 'ONEOFF',"CREDIT_LIMIT"]
print(len(col_key_kpi))
print(creditcarddata_org.shape[1])
# Out:
# 11
# 27

# %%
org_numeric = creditcarddata_org._get_numeric_data()

# %%
#5 cluster dataframe with labels
cluster_df_4 = pd.concat([org_numeric,pd.Series(km_4.labels_,name="Cluster_4")], axis = 1)

# %%
cluster_df_4.shape
# Out:
# (8950, 26)

# %%
grouped_cluster_df_4 =  cluster_df_4.groupby('Cluster_4').apply(lambda x:x.mean()).T
grouped_cluster_df_4
# Out:
# Cluster_4                                   0            1            2  \
# BALANCE                            787.049495  2183.797783  1428.280789
# BALANCE_FREQUENCY                    0.818484     0.884981     0.833477
# PURCHASES                          546.072842     2.409819   787.185883
# ONEOFF_PURCHASES                     0.059838     0.488811   787.081989
# INSTALLMENTS_PURCHASES             546.975954     1.952859     0.172507
# CASH_ADVANCE                       351.517524  2037.877426   857.287323
# PURCHASES_FREQUENCY                  0.705652     0.004952     0.320261
# ONEOFF_PURCHASES_FREQUENCY           0.000144     0.000599     0.319925
# PURCHASES_INSTALLMENTS_FREQUENCY     0.669405     0.003597     0.000443
# CASH_ADVANCE_FREQUENCY               0.045535     0.277222     0.123728
# CASH_ADVANCE_TRX                     0.995038     6.554710     2.863467
# PURCHASES_TRX                       12.101488     0.060419     7.118933
# ...

# %%
cluster_df_4.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE', 'Monthly_Avg_Purchase', 'Balance_Credit_Ratio',
#        'Monthly_Cash_Advance', 'Total_Payment_Ratio',
#        'BOTH_ONEOFF_INSTALLMENTS', 'INSTALLMENTS', 'NONE', 'ONEOFF',
#        'Cluster_4'],
#       dtype='object')

# %%
plt.figure(figsize=(3,3))
grouped_cluster_df_4.loc[['BALANCE','PURCHASES','CASH_ADVANCE','PAYMENTS'],:].plot.bar()
plt.grid()

# %%
plt.figure(figsize=(3,3))
grouped_cluster_df_4.loc[['BOTH_ONEOFF_INSTALLMENTS', 'INSTALLMENTS', 'NONE', 'ONEOFF'],:].plot.bar()
plt.grid()
